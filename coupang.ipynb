# %%
import requests
from bs4 import BeautifulSoup
import openpyxl

# %%
work_book = openpyxl.Workbook()
work_sheet = work_book.active
work_sheet.title = '쿠팡_탑_100'
work_sheet.column_dimensions['A'].width = 10
work_sheet.column_dimensions['B'].width = 60
work_sheet.column_dimensions['C'].width = 15
work_sheet.append(['순위','상품명','가격'])

# %%
res = requests.get('https://www.coupang.com/np/categories/194276?listSize=120&brand=&offerCondition=&filterType=&isPriceRange=false&minPrice=&maxPrice=&page=1&channel=user&fromComponent=N&selectedPlpKeepFilter=&sorter=bestAsc&filter=&rating=0',headers={'User-Agent':'Mozilla/5.0'})
soup = BeautifulSoup(res.content,'html.parser')
data =soup.select('dl.baby-product-wrap')

# %%
for index, name_price in enumerate(data): 
    product_name = name_price.select_one('div.name')
    product_price = name_price.select_one('strong.price-value')
    print(index+1, product_name.get_text().strip('\n').strip(), product_price.get_text().strip())
    work_sheet.append([index+1, product_name.get_text().strip('\n').strip(), product_price.get_text().strip()])
# Out:
# 1 페이브 프리미엄 브라질 산타루시아 싱글 오리진 원두, 홀빈, 200g 9,810
# 2 페이브 스페셜티 인도 콘다드칸 싱글 오리진 원두, 홀빈, 200g 9,810
# 3 농심 신라면 120g x 5p + 안성탕면 125g x 5p + 얼큰 너구리 120g x 5p + 짜파게티 140g x 5p, 1세트 14,500
# 4 돌 아보카도 대용량팩, 1kg, 1팩 9,900
# 5 충남세도 GAP 인증 대추방울토마토, 1kg, 1박스 10,400
# 6 매일유업 무항생제인증 슬로우밀크, 190ml, 24개 15,270
# 7 외갓집 케이준 통살치킨텐더 & 소스 (냉동), 1.2kg, 1개 12,290
# 8 곰곰 돌돌말이 무연골 대패 삼겹살 (냉동), 1kg, 1개 11,500
# 9 곰곰 국내산 신선한 감자, 1kg, 1봉 2,990
# 10 탐사수, 500ml, 40개 8,390
# 11 파머스팩 한돈 모듬 구이용 (냉장), 1kg, 1개 17,900
# 12 곰곰 부대찌개 (냉동), 1kg, 2개 12,940
# 13 참맛나라 신선한 알이 듬뿍 알탕, 1265g, 1개 12,900
# 14 곰곰 채소믹스, 1kg, 1개 9,890
# 15 셰프초이스 춘천식닭갈비 (냉장), 1kg, 1개 12,900
# 16 곰곰 버터미니크루아상, 30g, 15개입 9,490
# 17 서울우유 1급A우유, 2300ml, 1개 5,280
# 18 푸른초원 자연우유, 2300ml, 1개 4,580
# 19 프라임 부채살 스테이크컷 (냉장), 400g, 1개 12,400
# 20 맑은물에 국산콩 100% 촌두부, 300g, 2개 3,980
# 21 GAP 인증 국내산 햇 호박고구마, 1.5kg, 1박스 10,700
# 22 곰곰 납작한 떡갈비 (냉동), 1000g, 1개 9,180
# 23 맛있는 햇 밤고구마 한입사이즈, 1.5kg, 1봉 7,590
# 24 맛있는 햇 호박고구마, 1.5kg, 1박스 12,990
# ...

# %%
work_book.save('coupang_top_100.xlsx')
work_book.close()
